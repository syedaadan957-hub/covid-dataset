# %%
#Why do we use Pandas in data analysis?
#Because it helps load, clean, modify, and analyze data easily.
import pandas as pd

# %%
covid=pd.read_csv(r'c:\Users\LENOVO\Downloads\4. covid_19_data.csv')

# %%
covid.info() #Number of rows and columns,Column data types,Missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
covid.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid.tail()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
covid.shape
# Out:
# (321, 6)

# %%
covid.isnull()
# Out:
#       Date  State  Region  Confirmed  Deaths  Recovered
# 0    False   True   False      False   False      False
# 1    False   True   False      False   False      False
# 2    False   True   False      False   False      False
# 3    False   True   False      False   False      False
# 4    False   True   False      False   False      False
# ..     ...    ...     ...        ...     ...        ...
# 316  False  False   False      False   False      False
# 317  False  False   False      False   False      False
# 318  False  False   False      False   False      False
# 319  False  False   False      False   False      False
# 320  False  False   False      False   False      False
#
# [321 rows x 6 columns]

# %%
covid.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
covid.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
covid["Region"].value_counts()
# Out:
# Region
# US                58
# Mainland China    31
# Canada            15
# UK                11
# France            11
#                   ..
# Vietnam            1
# Zambia             1
# Zimbabwe           1
# Hong Kong          1
# Macau              1
# Name: count, Length: 187, dtype: int64

# %%
import seaborn as sb #For advanced and attractive visualization
import matplotlib.pyplot as plt #For creating simple graphs.

# %%
sb.heatmap(covid.isnull())
plt.show()

# %%
plt.plot(covid["Confirmed"])

# %%
covid.groupby('Region')[['Confirmed','Recovered']].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %%
sum_1 = covid.groupby('Region')['Confirmed'].sum()
sum_1.sort_values(ascending=False)
# Out:
# Region
# US                  1039909
# Spain                236899
# Italy                203591
# France               166543
# UK                   166441
#                      ...
# Mauritania                8
# Papua New Guinea          8
# Bhutan                    7
# Yemen                     6
# Western Sahara            6
# Name: Confirmed, Length: 187, dtype: int64

# %%
sum_1 = covid.groupby('Region')['Confirmed'].sum()
sum_1.sort_values(ascending=True)
# Out:
# Region
# Yemen                          6
# Western Sahara                 6
# Bhutan                         7
# Mauritania                     8
# Sao Tome and Principe          8
#                           ...
# UK                        166441
# France                    166543
# Italy                     203591
# Spain                     236899
# US                       1039909
# Name: Confirmed, Length: 187, dtype: int64

# %%
lesser=covid[covid.Confirmed>10]
lesser.sort_values('Confirmed')
# Out:
#           Date       State      Region  Confirmed  Deaths  Recovered
# 318  4/29/2020       Yukon      Canada         11       0          0
# 256  4/29/2020  Montserrat          UK         11       1          2
# 144  4/29/2020         NaN  Seychelles         11       0          6
# 217  4/29/2020   Greenland     Denmark         11       0         11
# 27   4/29/2020         NaN     Burundi         11       1          4
# ..         ...         ...         ...        ...     ...        ...
# 57   4/29/2020         NaN      France     165093   24087      48228
# 168  4/29/2020         NaN          UK     165221   26097          0
# 80   4/29/2020         NaN       Italy     203591   27682      71252
# 153  4/29/2020         NaN       Spain     236899   24275     132929
# 265  4/29/2020    New York          US     299691   23477          0
#
# [301 rows x 6 columns]

# %%
covid.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
maxonly_covid=covid.groupby('Region')["Confirmed"].max()
maxonly_covid.sort_values(ascending=False)
# Out:
# Region
# US                  299691
# Spain               236899
# Italy               203591
# UK                  165221
# France              165093
#                      ...
# Mauritania               8
# Papua New Guinea         8
# Bhutan                   7
# Yemen                    6
# Western Sahara           6
# Name: Confirmed, Length: 187, dtype: int64

# %%
min_1 = covid.groupby('Region')['Deaths'].min()
min_1.sort_values(ascending=True)
# Out:
# Region
# Australia        0
# Bhutan           0
# Cambodia         0
# Fiji             0
# Dominica         0
#              ...
# Iran          5957
# Germany       6467
# Belgium       7501
# Spain        24275
# Italy        27682
# Name: Deaths, Length: 187, dtype: int64

# %%
covid.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
covid[(covid['Region']=='India')&(covid['Date']<='4/29/2020')].groupby
# Out:
# <bound method DataFrame.groupby of          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437>

# %%
covid.sort_values(by=["Recovered"],ascending=False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 290  4/29/2020    Saskatchewan   Canada        383       6          0
# 299  4/29/2020    South Dakota       US       2373      13          0
# 298  4/29/2020  South Carolina       US       5882     231          0
# 302  4/29/2020       Tennessee       US      10366     195          0
# 303  4/29/2020           Texas       US      27257     754          0
#
# [321 rows x 6 columns]

# %%
covid.sort_values(by=["Recovered","Deaths"],ascending=False)
# Out:
#           Date                      State   Region  Confirmed  Deaths  \
# 153  4/29/2020                        NaN    Spain     236899   24275
# 285  4/29/2020                  Recovered       US          0       0
# 61   4/29/2020                        NaN  Germany     161539    6467
# 76   4/29/2020                        NaN     Iran      93657    5957
# 80   4/29/2020                        NaN    Italy     203591   27682
# ..         ...                        ...      ...        ...     ...
# 259  4/29/2020              New Brunswick   Canada        118       0
# 272  4/29/2020      Northwest Territories   Canada          5       0
# 279  4/29/2020       Prince Edward Island   Canada         27       0
# 289  4/29/2020  Saint Pierre and Miquelon   France          1       0
# 318  4/29/2020                      Yukon   Canada         11       0
#
#      Recovered
# 153     132929
# 285     120720
# 61      120400
# 76       73791
# 80       71252
# ..         ...
# ...
